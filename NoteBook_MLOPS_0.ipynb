# %%
print("Le MLOPS c'est génial !")
# Out:
# Le MLOPS c'est génial !

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

# %%
q2 = a + b
# Out:
# array([5, 7, 9])

# %%
q3 = a - b
# Out:
# array([-3, -3, -3])

# %%
q4 = a + 10
# Out:
# array([11, 12, 13])

# %%
q5 = b + 10
# Out:
# array([14, 15, 16])

# %%
q6 = a == b
# Out:
# array([False, False, False])

# %%
q7 = np.concatenate((a,b))
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
plt.plot(np.linspace(-10, 10, 1000), np.linspace(-10, 10, 1000)**2, c = "red", ls = "--")

# %%
plt.plot(np.linspace(-10, 10, 1000), 2 * np.linspace(-10, 10, 1000)**2 + 3, c = "blue", ls = "-")

# %%
plt.plot(np.linspace(-10, 10, 1000), -1 * np.linspace(-10, 10, 1000)**2 + 3, c = "black", ls = "-.")

# %%
plt.plot(np.linspace(-10, 10, 1000), 2 * np.linspace(-10, 10, 1000)**2 + 3, c = "blue", ls = "-")
plt.plot(np.linspace(-10, 10, 1000), -1 * np.linspace(-10, 10, 1000)**2 + 3, c = "black", ls = "-.")
plt.title("De très belles courbes")
plt.xlabel("L'axe des abscisse")
plt.ylabel("L'axe des ordonnées")
# Out:
# Text(0, 0.5, "L'axe des ordonnées")
